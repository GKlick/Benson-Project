# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/jakebartolone/ds/metis/turnstile_180922.txt')

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6759219
# 1  REGULAR  6759234
# 2  REGULAR  6759251
# 3  REGULAR  6759330
# 4  REGULAR  6759538
#
#    EXITS
# 0                                            2291425
# 1                                            2291429
# 2                                            2291453
# 3                                            2291532
# 4                                            2291574

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               ',
#        'entry_count'],
#       dtype='object')

# %%
df.rename({'EXITS                                                               ': 'EXITS'}, axis = 'columns', inplace = True)

# %%
df = df.assign(entry_count = df['ENTRIES'] - df['ENTRIES'].shift(1))

# %%
df.head(15)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  20:00:00
# ...

# %%
df = df.assign(exit_count = df['EXITS'] - df['EXITS'].shift(1))

# %%
df.head(15)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/15/2018  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  09/16/2018  20:00:00
# ...
